# %%
"a b c".split(" ")
# Out:
# ['a', 'b', 'c']

# %%
from numpy import *
from matplotlib.pyplot import *

x = linspace(0, 2*pi)
plot(x, sin(x), label=r'$\sin(x)$')
plot(x, cos(x), 'ro', label=r'$\cos(x)$')
title(r'Sin and Cos')
legend()
show()
